# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv("../yfinance_project/stock_hk.csv")

# %%
df
# Out:
#       Unnamed: 0        Date  Close   High    Low   Open    Volume  \
# 0              0  2025-01-02  0.090  0.090  0.086  0.095    104000
# 1              1  2025-01-03  0.090  0.090  0.090  0.090         0
# 2              2  2025-01-06  0.085  0.090  0.085  0.086    208000
# 3              3  2025-01-07  0.087  0.087  0.083  0.083     76009
# 4              4  2025-01-08  0.086  0.086  0.081  0.083    184000
# ...          ...         ...    ...    ...    ...    ...       ...
# 1355         267  2026-02-02  0.065  0.068  0.063  0.066   3960000
# 1356         268  2026-02-03  0.065  0.067  0.063  0.065   3140000
# 1357         269  2026-02-04  0.065  0.065  0.063  0.063    320000
# 1358         270  2026-02-05  0.063  0.067  0.063  0.065   3300000
# 1359         271  2026-02-06  0.082  0.085  0.063  0.064  51880000
#
#                Stock
# 0       NANFANG COMM
# 1       NANFANG COMM
# 2       NANFANG COMM
# 3       NANFANG COMM
# 4       NANFANG COMM
# ...              ...
# 1355  SINO GOLF HOLD
# 1356  SINO GOLF HOLD
# 1357  SINO GOLF HOLD
# 1358  SINO GOLF HOLD
# 1359  SINO GOLF HOLD
#
# [1360 rows x 8 columns]

# %%
df.Date = df.Date.astype('datetime64[ns]')

# %%
print(df.Stock.unique())
st=input("enter stock name=")
r=df[df.Stock==st]

sb.lineplot(x=r.Date,y=r.Close)
plt.show()
# Out:
# ['NANFANG COMM' 'DRAGON MINING' 'KINGS STONE' 'PUTIAN COMM'
#  'SINO GOLF HOLD']
# enter stock name= DRAGON MINING
